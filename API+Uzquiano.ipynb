# %% [markdown]
# ***
# # Importes
# ***

# %%
import requests
import json
import pandas as pd
from sodapy import Socrata

# %% [markdown]
# ***
# # Primera API
# ***

# %%
# https://www.healthit.gov/data/api
url='https://www.healthit.gov/data/open-api?source=ONC_HITECH_Grantee_List.csv'
df= requests.get(url)
print(df)
# Out:
# <Response [200]>

# %%
df.text
# Out:
# '[\n    {\n        "hitech_prgm": "Beacon Communities Program",\n        "hitech_sub_prgm": "Beacon Communities Program",\n        "hitech_prgm_website": "http:\\/\\/healthit.gov\\/policy-researchers-implementers\\/beacon-community-program",\n        "hitech_prgm_role": "Program Obligations",\n        "consortia_region": "",\n        "grantee_name": "",\n        "org_name": "",\n        "federal_funding": "249,999,927.00",\n        "region": "National",\n        "region_code": "US",\n        "zip_code": "",\n        "grantee_website": "http:\\/\\/healthit.gov\\/policy-researchers-implementers\\/beacon-community-program",\n        "grantee_website_url": "http:\\/\\/healthit.gov\\/policy-researchers-implementers\\/beacon-community-program"\n    },\n    {\n        "hitech_prgm": "Beacon Communities Program",\n        "hitech_sub_prgm": "Beacon Communities Program",\n        "hitech_prgm_website": "http:\\/\\/healthit.gov\\/policy-researchers-implementers\\/beacon-community-program",\n  
# ...

# %%
texto=df.text
json.loads(texto)
# Out:
# [{'hitech_prgm': 'Beacon Communities Program',
#   'hitech_sub_prgm': 'Beacon Communities Program',
#   'hitech_prgm_website': 'http://healthit.gov/policy-researchers-implementers/beacon-community-program',
#   'hitech_prgm_role': 'Program Obligations',
#   'consortia_region': '',
#   'grantee_name': '',
#   'org_name': '',
#   'federal_funding': '249,999,927.00',
#   'region': 'National',
#   'region_code': 'US',
#   'zip_code': '',
#   'grantee_website': 'http://healthit.gov/policy-researchers-implementers/beacon-community-program',
#   'grantee_website_url': 'http://healthit.gov/policy-researchers-implementers/beacon-community-program'},
#  {'hitech_prgm': 'Beacon Communities Program',
#   'hitech_sub_prgm': 'Beacon Communities Program',
#   'hitech_prgm_website': 'http://healthit.gov/policy-researchers-implementers/beacon-community-program',
#   'hitech_prgm_role': 'Recipient',
#   'consortia_region': '',
#   'grantee_name': 'Eastern Maine Healthcare Systems',
# ...

# %%
jsondata=json.loads(texto)
df2=pd.DataFrame.from_dict(jsondata)
df2
# Out:
#                                     hitech_prgm  \
# 0                    Beacon Communities Program
# 1                    Beacon Communities Program
# 2                    Beacon Communities Program
# 3                    Beacon Communities Program
# 4                    Beacon Communities Program
# ..                                          ...
# 287  The Community Health Peer Learning Program
# 288  The Community Health Peer Learning Program
# 289  The Community Health Peer Learning Program
# 290  The Community Health Peer Learning Program
# 291
#
#                                 hitech_sub_prgm  \
# 0                    Beacon Communities Program
# 1                    Beacon Communities Program
# 2                    Beacon Communities Program
# 3                    Beacon Communities Program
# 4                    Beacon Communities Program
# ..                                          ...
# 287  The Community Health Peer Learning Program
# ...

# %%
df2.shape
# Out:
# (292, 13)

# %% [markdown]
# ***
# # Segunda API
# ***

# %%
url98='https://www.healthit.gov/data/open-api?source=performance-measures.csv'
df98= requests.get(url98)
print(df98)
# Out:
# <Response [200]>

# %%
df98.text
# Out:
# '[\n    {\n        "measure": "Percent of office-based physicians who have adopted a Basic EHR",\n        "measure_year": "2009",\n        "measure_type": "actual",\n        "measure_value": "21",\n        "measure_status": ""\n    },\n    {\n        "measure": "Percent of office-based physicians who have adopted a Basic EHR",\n        "measure_year": "2009",\n        "measure_type": "target",\n        "measure_value": "",\n        "measure_status": ""\n    },\n    {\n        "measure": "Percent of office-based physicians who have adopted a Basic EHR",\n        "measure_year": "2010",\n        "measure_type": "actual",\n        "measure_value": "28",\n        "measure_status": ""\n    },\n    {\n        "measure": "Percent of office-based physicians who have adopted a Basic EHR",\n        "measure_year": "2010",\n        "measure_type": "target",\n        "measure_value": "25",\n        "measure_status": ""\n    },\n    {\n        "measure": "Percent of office-based physicians who ha
# ...

# %%
texto98=df98.text
json.loads(texto98)
# Out:
# [{'measure': 'Percent of office-based physicians who have adopted a Basic EHR',
#   'measure_year': '2009',
#   'measure_type': 'actual',
#   'measure_value': '21',
#   'measure_status': ''},
#  {'measure': 'Percent of office-based physicians who have adopted a Basic EHR',
#   'measure_year': '2009',
#   'measure_type': 'target',
#   'measure_value': '',
#   'measure_status': ''},
#  {'measure': 'Percent of office-based physicians who have adopted a Basic EHR',
#   'measure_year': '2010',
#   'measure_type': 'actual',
#   'measure_value': '28',
#   'measure_status': ''},
#  {'measure': 'Percent of office-based physicians who have adopted a Basic EHR',
#   'measure_year': '2010',
#   'measure_type': 'target',
#   'measure_value': '25',
#   'measure_status': ''},
#  {'measure': 'Percent of office-based physicians who have adopted a Basic EHR',
#   'measure_year': '2011',
#   'measure_type': 'actual',
#   'measure_value': '34',
#   'measure_status': ''},
# ...

# %%
jsondata98=json.loads(texto98)
df99=pd.DataFrame.from_dict(jsondata98)
df99
# Out:
#                                                measure measure_year  \
# 0    Percent of office-based physicians who have ad...         2009
# 1    Percent of office-based physicians who have ad...         2009
# 2    Percent of office-based physicians who have ad...         2010
# 3    Percent of office-based physicians who have ad...         2010
# 4    Percent of office-based physicians who have ad...         2011
# ..                                                 ...          ...
# 332  Number of providers registered with ONC Region...         2015
# 333  Number of providers registered with ONC Region...         2015
# 334  Number of providers registered with ONC Region...         2016
# 335  Number of providers registered with ONC Region...         2016
# 336                                                             NaN
#
#     measure_type measure_value measure_status
# 0         actual            21
# 1         target
# 2         actual            28
# ...

# %% [markdown]
# ***
# # Tercera API
# ***

# %%
# !pip install pandas
# !pip install sodapy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("chronicdata.cdc.gov", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(chronicdata.cdc.gov,
#                  MyAppToken,
#                  username="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("7b9s-s8ck", limit=10000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results_df
# Out:
#       year locationabbr locationdesc geographiclevel datasource  \
# 0     1999           AL      Autauga          County       NVSS
# 1     2013           AL      Autauga          County       NVSS
# 2     2014           AL      Autauga          County       NVSS
# 3     2005           AL      Autauga          County       NVSS
# 4     2012           AL      Autauga          County       NVSS
# ...    ...          ...          ...             ...        ...
# 9995  2013           AL      Bullock          County       NVSS
# 9996  2014           AL      Bullock          County       NVSS
# 9997  2015           AL      Bullock          County       NVSS
# 9998  2003           AL      Bullock          County       NVSS
# 9999  2000           AL      Bullock          County       NVSS
#
#                         class              topic data_value data_value_unit  \
# 0     Cardiovascular Diseases  All heart disease         NA     per 100,000
# ...

# %%
results_df = results_df.drop(['data_value_unit', 'data_value_type', 'confidence_limit_low', 'confidence_limit_high', 'stratificationcategory1', 'stratificationcategory2', 'stratificationcategory3', 'data_value_footnote_symbol', 'data_value'], axis=1)
results_df
# Out:
#       year locationabbr locationdesc geographiclevel datasource  \
# 0     1999           AL      Autauga          County       NVSS
# 1     2013           AL      Autauga          County       NVSS
# 2     2014           AL      Autauga          County       NVSS
# 3     2005           AL      Autauga          County       NVSS
# 4     2012           AL      Autauga          County       NVSS
# ...    ...          ...          ...             ...        ...
# 9995  2013           AL      Bullock          County       NVSS
# 9996  2014           AL      Bullock          County       NVSS
# 9997  2015           AL      Bullock          County       NVSS
# 9998  2003           AL      Bullock          County       NVSS
# 9999  2000           AL      Bullock          County       NVSS
#
#                         class              topic data_value_footnote  \
# 0     Cardiovascular Diseases  All heart disease    Value suppressed
# ...

# %% [markdown]
# ***
# # Cuarta API y Basic data Wrangling
# ***

# %%
#url = 'https://chronicdata.cdc.gov/resource/7b9s-s8ck.json'
url= 'https://chronicdata.cdc.gov/resource/kztq-p2jf.json'
df= requests.get(url)
print(df)
# Out:
# <Response [200]>

# %%
df.text
# Out:
# '[{"row_id":"NVSS~2003~32~NV005~AGE08~Crude","year":"2003","locationabbr":"NV","locationdesc":"Nevada","datasource":"NVSS","priorityarea1":"None","priorityarea2":"None","priorityarea3":"None","priorityarea4":"None","category":"Cardiovascular Diseases","topic":"Heart Failure","indicator":"Rate of heart failure mortality among US adults (18+); NVSS","data_value_type":"Crude","data_value_unit":"Rate per 100,000","data_value":"333.7","data_value_alt":"333.7","lowconfidencelimit":"333.6","highconfidencelimit":"333.8","break_out_category":"Age","break_out":"75+","categoryid":"C1","topicid":"T5","indicatorid":"NV005","data_value_typeid":"Crude","breakoutcategoryid":"BOC03","breakoutid":"AGE08","locationid":"32","geolocation":{"type":"Point","coordinates":[-117.07184056399967,39.493240390000494]},":@computed_region_bxsw_vy29":"10",":@computed_region_he4y_prf8":"481"}\n,{"row_id":"NVSS~2007~59~NV001~AGE08~Crude","year":"2007","locationabbr":"US","locationdesc":"United States","datasource":"NV
# ...

# %%
texto=df.text
json.loads(texto)
# Out:
# [{'row_id': 'NVSS~2003~32~NV005~AGE08~Crude',
#   'year': '2003',
#   'locationabbr': 'NV',
#   'locationdesc': 'Nevada',
#   'datasource': 'NVSS',
#   'priorityarea1': 'None',
#   'priorityarea2': 'None',
#   'priorityarea3': 'None',
#   'priorityarea4': 'None',
#   'category': 'Cardiovascular Diseases',
#   'topic': 'Heart Failure',
#   'indicator': 'Rate of heart failure mortality among US adults (18+); NVSS',
#   'data_value_type': 'Crude',
#   'data_value_unit': 'Rate per 100,000',
#   'data_value': '333.7',
#   'data_value_alt': '333.7',
#   'lowconfidencelimit': '333.6',
#   'highconfidencelimit': '333.8',
#   'break_out_category': 'Age',
#   'break_out': '75+',
#   'categoryid': 'C1',
#   'topicid': 'T5',
#   'indicatorid': 'NV005',
#   'data_value_typeid': 'Crude',
#   'breakoutcategoryid': 'BOC03',
#   'breakoutid': 'AGE08',
#   'locationid': '32',
#   'geolocation': {'type': 'Point',
#    'coordinates': [-117.07184056399967, 39.493240390000494]},
# ...

# %%
jsondata=json.loads(texto)
df2=pd.DataFrame.from_dict(jsondata)
df2
# Out:
#                                         row_id  year locationabbr  \
# 0               NVSS~2003~32~NV005~AGE08~Crude  2003           NV
# 1               NVSS~2007~59~NV001~AGE08~Crude  2007           US
# 2               NVSS~2012~59~NV001~RAC07~Crude  2012           US
# 3               NVSS~2011~59~NV001~GEN02~Crude  2011           US
# 4               NVSS~2010~59~NV001~AGE05~Crude  2010           US
# ..                                         ...   ...          ...
# 995             NVSS~2009~02~NV001~AGE06~Crude  2009           AK
# 996             NVSS~2000~47~NV001~GEN02~Crude  2000           TN
# 997             NVSS~2017~55~NV001~AGE06~Crude  2017           WI
# 998             NVSS~2003~16~NV001~GEN02~Crude  2003           ID
# 999  NVSS~2008~49~NV001~GEN01~Age-Standardized  2008           UT
#
#       locationdesc datasource priorityarea1 priorityarea2 priorityarea3  \
# 0           Nevada       NVSS          None          None          None
# ...

# %%
df2.columns
# Out:
# Index(['row_id', 'year', 'locationabbr', 'locationdesc', 'datasource',
#        'priorityarea1', 'priorityarea2', 'priorityarea3', 'priorityarea4',
#        'category', 'topic', 'indicator', 'data_value_type', 'data_value_unit',
#        'data_value', 'data_value_alt', 'lowconfidencelimit',
#        'highconfidencelimit', 'break_out_category', 'break_out', 'categoryid',
#        'topicid', 'indicatorid', 'data_value_typeid', 'breakoutcategoryid',
#        'breakoutid', 'locationid', 'geolocation',
#        ':@computed_region_bxsw_vy29', ':@computed_region_he4y_prf8',
#        'data_value_footnote_symbol', 'data_value_footnote'],
#       dtype='object')

# %%
df2 = df2.drop(["priorityarea1","priorityarea2","priorityarea3","priorityarea4","geolocation","data_value_footnote_symbol","data_value_footnote",":@computed_region_bxsw_vy29",":@computed_region_he4y_prf8","row_id"], axis=1)
df2
# Out:
#      year locationabbr   locationdesc datasource                 category  \
# 0    2003           NV         Nevada       NVSS  Cardiovascular Diseases
# 1    2007           US  United States       NVSS  Cardiovascular Diseases
# 2    2012           US  United States       NVSS  Cardiovascular Diseases
# 3    2011           US  United States       NVSS  Cardiovascular Diseases
# 4    2010           US  United States       NVSS  Cardiovascular Diseases
# ..    ...          ...            ...        ...                      ...
# 995  2009           AK         Alaska       NVSS  Cardiovascular Diseases
# 996  2000           TN      Tennessee       NVSS  Cardiovascular Diseases
# 997  2017           WI      Wisconsin       NVSS  Cardiovascular Diseases
# 998  2003           ID          Idaho       NVSS  Cardiovascular Diseases
# 999  2008           UT           Utah       NVSS  Cardiovascular Diseases
#
#                             topic  \
# 0                   Heart Failure
# ...

# %%
df2 = df2.dropna()
df2
# Out:
#      year locationabbr   locationdesc datasource                 category  \
# 0    2003           NV         Nevada       NVSS  Cardiovascular Diseases
# 1    2007           US  United States       NVSS  Cardiovascular Diseases
# 2    2012           US  United States       NVSS  Cardiovascular Diseases
# 3    2011           US  United States       NVSS  Cardiovascular Diseases
# 4    2010           US  United States       NVSS  Cardiovascular Diseases
# ..    ...          ...            ...        ...                      ...
# 995  2009           AK         Alaska       NVSS  Cardiovascular Diseases
# 996  2000           TN      Tennessee       NVSS  Cardiovascular Diseases
# 997  2017           WI      Wisconsin       NVSS  Cardiovascular Diseases
# 998  2003           ID          Idaho       NVSS  Cardiovascular Diseases
# 999  2008           UT           Utah       NVSS  Cardiovascular Diseases
#
#                             topic  \
# 0                   Heart Failure
# ...

# %%
df2.isnull().any()
# Out:
# year                   False
# locationabbr           False
# locationdesc           False
# datasource             False
# category               False
# topic                  False
# indicator              False
# data_value_type        False
# data_value_unit        False
# data_value             False
# data_value_alt         False
# lowconfidencelimit     False
# highconfidencelimit    False
# break_out_category     False
# break_out              False
# categoryid             False
# topicid                False
# indicatorid            False
# data_value_typeid      False
# breakoutcategoryid     False
# breakoutid             False
# locationid             False
# dtype: bool

# %%
df2.isna().sum()
# Out:
# year                   0
# locationabbr           0
# locationdesc           0
# datasource             0
# category               0
# topic                  0
# indicator              0
# data_value_type        0
# data_value_unit        0
# data_value             0
# data_value_alt         0
# lowconfidencelimit     0
# highconfidencelimit    0
# break_out_category     0
# break_out              0
# categoryid             0
# topicid                0
# indicatorid            0
# data_value_typeid      0
# breakoutcategoryid     0
# breakoutid             0
# locationid             0
# dtype: int64

# %%
#df2.reset_index()
df2.groupby(by="year")

# %%
df2.describe()
# Out:
#         year locationabbr   locationdesc datasource                 category  \
# count    933          933            933        933                      933
# unique    19           52             52          1                        1
# top     2008           US  United States       NVSS  Cardiovascular Diseases
# freq      80           52             52        933                      933
#
#                                topic  \
# count                            933
# unique                             6
# top     Major Cardiovascular Disease
# freq                             828
#
#                                                 indicator data_value_type  \
# count                                                 933             933
# unique                                                  8               2
# top     Rate of major cardiovascular disease mortality...           Crude
# freq                                                  828             642
#
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 933 entries, 0 to 999
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   year                 933 non-null    object
#  1   locationabbr         933 non-null    object
#  2   locationdesc         933 non-null    object
#  3   datasource           933 non-null    object
#  4   category             933 non-null    object
#  5   topic                933 non-null    object
#  6   indicator            933 non-null    object
#  7   data_value_type      933 non-null    object
#  8   data_value_unit      933 non-null    object
#  9   data_value           933 non-null    object
#  10  data_value_alt       933 non-null    object
#  11  lowconfidencelimit   933 non-null    object
#  12  highconfidencelimit  933 non-null    object
#  13  break_out_category   933 non-null    object
#  14  break_out            933 non-null    object
# ...
